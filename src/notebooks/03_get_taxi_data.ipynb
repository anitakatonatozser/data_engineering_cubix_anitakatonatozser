# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
import json
import os

import pandas as pd
import requests

# %%
url = "https://data.cityofchicago.org/resource/wrvz-psew.json?trip_id=00000019ef3c0b419a9e6b1843b83530b79627a4"

headers = {"X-App-Token": os.environ.get("CHICAGO_API_TOKEN")}

response = requests.get(url, headers=headers)

data = response.json()

# %%
# response
data
# Out:
# [{'trip_id': '00000019ef3c0b419a9e6b1843b83530b79627a4',
#   'taxi_id': 'bda916a4fa3043f7e827751d9d8cada1239d574beb206d846e1d7d425b658d56aa23393b6866d3a19f9dca6c32d3a8642f14361c5d58dccebd42e398fee18e94',
#   'trip_start_timestamp': '2023-12-11T16:15:00.000',
#   'trip_end_timestamp': '2023-12-11T17:00:00.000',
#   'trip_seconds': '2572',
#   'trip_miles': '17.56',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081700',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.75',
#   'tips': '12.06',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '60.31',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.892042136',
# ...

# %%
url = f"https://data.cityofchicago.org/resource/wrvz-psew.json?$where=trip_start_timestamp >= '2023-08-06T00:00:00' AND trip_start_timestamp <= '2023-08-06T23:59:59'&$limit=30000"

headers = {"X-App-Token": os.environ.get("CHICAGO_API_TOKEN")}

response = requests.get(url, headers=headers)

data = response.json()

# %%
# len(data)
# Out:
# [{'trip_id': '5dfb4f3890caef5a5e4793f4ae6e9404f0e70f71',
#   'taxi_id': '9e402f28d4da35014d6f3171cf85336476cebfccf7904890ade2c60e59cbea30c5c169ee75b6d7e764d25d327b9c047a014c01673b61a9069d6bb6f7e023fe9c',
#   'trip_start_timestamp': '2023-08-06T23:45:00.000',
#   'trip_end_timestamp': '2023-08-07T00:15:00.000',
#   'trip_seconds': '1980',
#   'trip_miles': '16',
#   'pickup_community_area': '76',
#   'fare': '40.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5.5',
#   'trip_total': '46.25',
#   'payment_type': 'Credit Card',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '5ec3a3a2b34df96b4658f395bb7b4ab1784d140c',
#   'taxi_id': 'c1b8f1a1325ae6a1997df1977218627702035e8f17964dfe783245e174bd0f348ddfa74c01b0871dfa1cd3470d288d93df1b4a2d081eaea46f907e7f3ca717d9',
# ...

# %%
# Extract T-2 months' data

current_datetime = datetime.now() - relativedelta(months=2)

formatted_datetime = current_datetime.strftime("%Y-%m-%d")

url = f"https://data.cityofchicago.org/resource/ajtu-isnz.json?$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'&$limit=30000"

headers = {"X-App-Token": os.environ.get("CHICAGO_API_TOKEN")}

response = requests.get(url, headers=headers)

data = response.json()

# %%
data
# Out:
# [{'trip_id': '95a116b1b333e9db92b524510f534bc9fa40dc47',
#   'taxi_id': '0f3f29ac05b3574275f73ea36e2e0ff7ca74e41c8e72d1d1ab6e1556b3143f83d5bfb56d6594d19d79de8bd5321b9d185c7d81200761d50259860491e66d2a41',
#   'trip_start_timestamp': '2024-05-28T23:45:00.000',
#   'trip_end_timestamp': '2024-05-29T00:00:00.000',
#   'trip_seconds': '955',
#   'trip_miles': '5.27',
#   'pickup_community_area': '76',
#   'fare': '16.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '6',
#   'trip_total': '22.5',
#   'payment_type': 'Cash',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'fba0341003d3a776f5bc542c2309108d2db1a20f',
#   'taxi_id': '8a8499f6e991a3e9bee922bb11f3ff01dad26d1d5b365a70fd66ffe04c879fca221978ed4ea921efe6e339a58043b5360cfd07268c214771c90100b4712a215b',
# ...
