# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
import os

import pandas as pd
pd.set_option("display.max_columns", 30)
import requests

# %%
# Extract T-2 months' data

current_datetime = datetime.now() - relativedelta(months=2)
formatted_datetime = current_datetime.strftime("%Y-%m-%d")

url = f"https://data.cityofchicago.org/resource/ajtu-isnz.json?$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'&$limit=30000"

# headers = {"X-App-Token": os.environ.get("CHICAGO_API_TOKEN")}
# response = requests.get(url, headers=headers)

response = requests.get(url)

data = response.json()

# %%
# type(response)
# Out:
# [{'trip_id': 'b747a4013b7c3b168e7b158ac572a81ad1b0617f',
#   'taxi_id': 'bebdd992c4a9275f26e83e00649616f188674dc151a82f3de5b7e3400179683a3032ae5fa452f9105fd524f0f6d1296efc48081ec13ec25550d810d60865bfee',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:15:00.000',
#   'trip_seconds': '1425',
#   'trip_miles': '17.76',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.75',
#   'tips': '12.31',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '61.56',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'b44f15ac4498f7a8535d4d28b4c6287d53f0577d',
#   'taxi_id': 'f20c9c5845dab1e51799b959d378c102763d4b31d738da7ea1f7fee763a4c830854cf6025fbe42e7c37dddab03ef2cf43bc775bdd6c5a4114d307dbf415728a5',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:00:00.000',
#   'trip_seconds': '1368',
#   'trip_miles': '12.91',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '49',
#   'fare': '33.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '33.25',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.706587882',
#   'dropoff_centroid_longitude': '-87.623366512',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6233665115, 41.7065878819]}},
#  {'trip_id': 'b0517aedccf83b5f0854dee82814d90c2abcafbb',
#   'taxi_id': '58ba68a5ed675f1dd391281aa8853366f7759face1a388abf6b64c8a9e5f24d65de820eb60b293a3a8b6dbd48e8019439535d20faf2576989701a5936c4e77b8',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:15:00.000',
#   'trip_seconds': '1260',
#   'trip_miles': '0.5',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '77',
#   'fare': '26.5',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '31.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.9867118',
#   'dropoff_centroid_longitude': '-87.663416405',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6634164054, 41.9867117999]}},
#  {'trip_id': 'ae938970ae39e25f2efee494a1e0451c5af215b9',
#   'taxi_id': 'ac1f0defd00d6b7417e39256ebe1cad16b64955f9a64f2eaecee6f54e52ec118133f687c8b6603d6e9a27d86a8921fc30e1458e804686d05f9cb83751fac3382',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-30T23:45:00.000',
#   'trip_seconds': '420',
#   'trip_miles': '0',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '7.75',
#   'tips': '4',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'aafe7dae828bc1b521da6418496502f15e355c5e',
#   'taxi_id': '01480513a7f6f4664d6cc4c41ff3043ae6ecbc8cb17404f45de6db711747adf72cf309207bcde58413778d568f67a548640421aedac9a6f961b6919b6e662e8f',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:15:00.000',
#   'trip_seconds': '1632',
#   'trip_miles': '14.99',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '69',
#   'fare': '39',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '43',
#   'payment_type': 'Cash',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.763246799',
#   'dropoff_centroid_longitude': '-87.616134111',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6161341112, 41.7632467988]}},
#  {'trip_id': 'aaf2476882ad4a4e2baae0c1b4d6c2aae47a1bca',
#   'taxi_id': '5453573a470c75b36d908d4e664de1c937e68aae86c420191a43870a402b62ca9e81867fc2a769011873a9d7df93f43083246b9691db0c27e29126faacb84f19',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-30T23:45:00.000',
#   'trip_seconds': '402',
#   'trip_miles': '1.19',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '7',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '1.5',
#   'trip_total': '11',
#   'payment_type': 'Credit Card',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'aaefd4ab481ab7c6c3c436081338dc9ad735475a',
#   'taxi_id': '34f13b72cc0f5eee8a0827f77e3d51707f7cdf695e7b4af811cbe05dbf04e51a283ed57964735a325c40f366a69600cf83d5d187ecf9bd7f3e1da04c2675964c',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:00:00.000',
#   'trip_seconds': '1198',
#   'trip_miles': '9.01',
#   'pickup_community_area': '76',
#   'fare': '24.75',
#   'tips': '15',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '44.25',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'a9b2a3bfcafa387aaed2f4e4e6fb25c1bf284aa3',
#   'taxi_id': 'd938113dfa44ec7338aae788f1c21d3170a1e5992e5658f52b3a8691a75ed9d058c9d34f72d8f841afd143fa141703a25cf0b61ba18df17664206858ea3e57db',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:15:00.000',
#   'trip_seconds': '1575',
#   'trip_miles': '6.55',
#   'pickup_community_area': '6',
#   'dropoff_community_area': '28',
#   'fare': '12.06',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '12.06',
#   'payment_type': 'Mobile',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.944226601',
#   'pickup_centroid_longitude': '-87.655998182',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': 'a95d6e403db70545ca2f7a282ce70fcffc9e9304',
#   'taxi_id': '91a036e3de3c1f459f2664801ea9388870751ae14e196e5be1caa84093318244f75aad0dbecdb8f5f6d2fb9ceec9c03c57acb5309769a88c68d06a49b157dae8',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-30T23:45:00.000',
#   'trip_seconds': '585',
#   'trip_miles': '2.01',
#   'pickup_census_tract': '17031833000',
#   'dropoff_census_tract': '17031081000',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '9',
#   'tips': '1.76',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '10.76',
#   'payment_type': 'Mobile',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.88528132',
#   'pickup_centroid_longitude': '-87.6572332',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]},
#   'dropoff_centroid_latitude': '41.900265687',
#   'dropoff_centroid_longitude': '-87.63210922',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6321092196, 41.9002656868]}},
#  {'trip_id': 'a322ebfd683142f040d84dafeeaf8af1b9e8e7c0',
#   'taxi_id': 'f451123ff58e8ef1ca5e64de85da57d7cf463c5ee73e6ad1301d57c9ce7a1dc958cd2c34bc424919ca74e3fc9b6ab261bc7923a725a5c3da00f9b3138e5e0c1d',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:00:00.000',
#   'trip_seconds': '1112',
#   'trip_miles': '6.94',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '25',
#   'fare': '19.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '23.5',
#   'payment_type': 'Cash',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.890608853',
#   'dropoff_centroid_longitude': '-87.756046711',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7560467111, 41.8906088526]}},
#  {'trip_id': 'a297285115657332159b0292173d1876ac86fbc3',
#   'taxi_id': 'cb1a522e6e968cbebb7ce23e6775a4769de4aeb2154fa54eb45c6c949684eb78aa918edbcda68f595530660375a5b7968322174a9d4ed5b2002222b5c3e9ee71',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:30:00.000',
#   'trip_seconds': '2075',
#   'trip_miles': '2.93',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '19.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '23.25',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.980264315',
#   'dropoff_centroid_longitude': '-87.913624596',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'a2924247c91935986e57463661b2866de20cb4d0',
#   'taxi_id': '511d5a90fddd5d591ca80c1c2969c190f8ad2997c0b6e9d1776a3864f2536814f53b603888e6ca6fa11e0e8625b02db335ef976a9a36e8d35b7d714e38e55bef',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-30T23:45:00.000',
#   'trip_seconds': '316',
#   'trip_miles': '1.68',
#   'pickup_community_area': '4',
#   'dropoff_community_area': '14',
#   'fare': '9',
#   'tips': '2.3',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.3',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.975170943',
#   'pickup_centroid_longitude': '-87.687515515',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6875155152, 41.9751709433]},
#   'dropoff_centroid_latitude': '41.968069',
#   'dropoff_centroid_longitude': '-87.721559063',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7215590627, 41.968069]}},
#  {'trip_id': '9e76d3f0f6455c458fc2a4df636ebd7808b1e139',
#   'taxi_id': 'bfb5c2ad40103c9891e7ee4713e93ccd75e741099b7498884115f8ed4a13201f14f3f33a34a5eb231f66772204ee783613e46323926be4b819f202858d693ca5',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:00:00.000',
#   'trip_seconds': '646',
#   'trip_miles': '2.64',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '7',
#   'fare': '9.1',
#   'tips': '2.47',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '12.57',
#   'payment_type': 'Mobile',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '9d27f440d5a9d389ee11ab17d54cb837836bd0f5',
#   'taxi_id': 'd2c2d4128d6597a3b6db0bd0efa96e9914be3994f861bb17e50ad7fc458df68ab9d4ed2026ce6ef4e80874c993dd5c7a5a8779fbe04510495f793f7bebc31d21',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:15:00.000',
#   'trip_seconds': '1985',
#   'trip_miles': '26.66',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081600',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '64.5',
#   'tips': '14.6',
#   'tolls': '0',
#   'extras': '8',
#   'trip_total': '87.6',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.892072635',
#   'dropoff_centroid_longitude': '-87.628874157',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6288741572, 41.8920726347]}},
#  {'trip_id': '991b855c64f16b156981d90f796ce689c0c4acdc',
#   'taxi_id': 'eb7536e0b280d7842bd4448d3fc93ca078630c2f39f12279de652a8fbd162d414c7135f9ce6ce3672fe25ae365c4fafcd842b9ca8b370d54a62f71eab43679bb',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:00:00.000',
#   'trip_seconds': '1268',
#   'trip_miles': '16.02',
#   'pickup_community_area': '76',
#   'fare': '40',
#   'tips': '16.62',
#   'tolls': '0',
#   'extras': '26',
#   'trip_total': '83.12',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '962f2b9d5e12dd145cbb99e0d847fd9aa8b7ba7c',
#   'taxi_id': '1f25a2b2c1cf1bd6ad6733bfa6eacddf5c9475102bfcd76b39ecab3ebbb2bbbd03a359ed46994d173cc6ee81bb555cea2ab424228057ea4b4170c43cd226bff4',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:00:00.000',
#   'trip_seconds': '1260',
#   'trip_miles': '8.8',
#   'fare': '24.25',
#   'tips': '5.95',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '35.2',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency, LLC'},
#  {'trip_id': '8c7d05db94b3c9104972f947407f612aceed2956',
#   'taxi_id': '8d4a87f9c4150448fa72263beee9f6166bbbb39812be81ea983c70bc9b973d64f40650751b2820249222aa26ae738b3d1d5487535204a705defd90c507ccd185',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:15:00.000',
#   'trip_seconds': '1171',
#   'trip_miles': '12.58',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '22',
#   'fare': '32',
#   'tips': '7.3',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '43.8',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': '8b265da0d8e42551a1eb713eb1d8a6b3fa48b07c',
#   'taxi_id': '1226e3d8b86299171525b37f43403bc64e9fa3f8aa450209dd7d40a968237353b605ae9085f43da45cc896cb43a4371c3952e92bdc2ea7600c9e95fcdd297f2c',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:00:00.000',
#   'trip_seconds': '600',
#   'trip_miles': '5.1',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031760801',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '13.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '17.25',
#   'payment_type': 'Cash',
#   'company': 'Choice Taxi Association',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.982272929',
#   'dropoff_centroid_longitude': '-87.841586432',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.8415864319, 41.9822729289]}},
#  {'trip_id': '8465317f406964e992e49f01063ada5cb5d16372',
#   'taxi_id': '4794c36af4c1852d90b5c8cf5f9f6cd38a8b9c1b68cf486e38a89f60c9226e0987ee8529cb2d550ff6c91ec8ff59e3b0607eccdfee8405f0edeb31023c1b50af',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:15:00.000',
#   'trip_seconds': '1218',
#   'trip_miles': '16.78',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031839100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '41.25',
#   'tips': '7.01',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '53.76',
#   'payment_type': 'Credit Card',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.880994471',
#   'dropoff_centroid_longitude': '-87.632746489',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]}},
#  {'trip_id': '83d53e1273bd68673dbe3730f0f44fe5f81c5baf',
#   'taxi_id': '2d5970d2ce86bb2ea404275fbdd5fce016b817e71997614162a332641f9f7ab200a73fc14415ef76efa5eaf9877158da4da6f88a4f789c48710c1a23d6774602',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-30T23:45:00.000',
#   'trip_seconds': '459',
#   'trip_miles': '0',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '28',
#   'fare': '9',
#   'tips': '2.88',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.88',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '83d2c371778724e04aedb28209d91b4789514174',
#   'taxi_id': '4d383b5d473f9402a59c74dd17d0d1c4d7b2f2c640bd0648c03c999f45777fe740fc5aa1dd7549cef55a660f3b5865e46fba8265851d12c6864235b037b33806',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-31T00:30:00.000',
#   'trip_seconds': '2820',
#   'trip_miles': '0.4',
#   'pickup_community_area': '12',
#   'dropoff_community_area': '12',
#   'fare': '28.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '28.5',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.993930128',
#   'pickup_centroid_longitude': '-87.758353588',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7583535876, 41.9939301285]},
#   'dropoff_centroid_latitude': '41.993930128',
#   'dropoff_centroid_longitude': '-87.758353588',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7583535876, 41.9939301285]}},
#  {'trip_id': '80f58f66213196901a803598db38d6122dff39ab',
#   'taxi_id': '0f831bff43d83f396f2e4950126c6137dcdb60fb4c8580ffe860203747a83a789b22f2f9e4fbdd0dd8ed8c310366d8935228ddbcadf708fb9691ca5dd1b6c802',
#   'trip_start_timestamp': '2024-05-30T23:45:00.000',
#   'trip_end_timestamp': '2024-05-30T23:45:00.000',
#   'trip_seconds': '447',
#   'trip_miles': '3.84',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '10',
#   'fare': '12.25',
#   'tips': '2.74',
#   'tolls': '0',
#   'extras': '5.5',
#   'trip_total': '20.99',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41

#   'payment_type': 'Credit Card',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '14cd62ee746521a9da124bb2b0e133f3d0d6482a',
#   'taxi_id': '646880db83de7381a22c7f6931e1ce522ecfe56d76cc77623ce598cb5059150cea2d5919188cd25d84fb1ec571292a37ba2da97ee1f3ad7529a7a3d9d16bbee0',
#   'trip_start_timestamp': '2024-05-30T22:15:00.000',
#   'trip_end_timestamp': '2024-05-30T22:45:00.000',
#   'trip_seconds': '1672',
#   'trip_miles': '16.58',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '24',
#   'fare': '40.75',
#   'tips': '6.94',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '53.19',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '1341152f9d41b3db6ec6e674f04137549ad1ca3c',
#   'taxi_id': '17a313ad40ea410818634782c7202abda7ce5289dc03f9e09593f69bebeed12b0822b476540ea1b0b15d01e84a749139ae99a7659ff7fd090722c4601aa55a1a',
#   'trip_start_timestamp': '2024-05-30T22:15:00.000',
#   'trip_end_timestamp': '2024-05-30T23:00:00.000',
#   'trip_seconds': '2006',
#   'trip_miles': '20.67',
#   'pickup_community_area': '30',
#   'dropoff_community_area': '52',
#   'fare': '52.76',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '52.76',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.839086906',
#   'pickup_centroid_longitude': '-87.714003807',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.714003807, 41.8390869059]},
#   'dropoff_centroid_latitude': '41.707311449',
#   'dropoff_centroid_longitude': '-87.534902901',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5349029012, 41.707311449]}},
#  {'trip_id': '12040765a25c3f8e4285dfe6fea2137d6168eb21',
#   'taxi_id': '95ec993d14762b5d1b7e4d2b30661da6b49b7f0c1eb20f210fbd5d49cf70de5990df25d5617483c3467e94e6a0670c629de4a83bdfd545e70444da871b70925b',
#   'trip_start_timestamp': '2024-05-30T22:15:00.000',
#   'trip_end_timestamp': '2024-05-30T23:00:00.000',
#   'trip_seconds': '2092',
#   'trip_miles': '18.03',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081401',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '44.75',
#   'tips': '7.39',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '56.64',
#   'payment_type': 'Mobile',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.89503345',
#   'dropoff_centroid_longitude': '-87.619710672',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6197106717, 41.8950334495]}},
#  {'trip_id': '118b33ca326ae27f1e7d4daf1f3b412553182ab0',
#   'taxi_id': 'f54b11bc86d1ab32945f60547e15cbdc14a3b017b2a0ee92fcf22f9e378c5ed919e3d8aca21c82570c0d3562f9d87efc3db6b319a8c2b7ceb722043ebdefb769',
#   'trip_start_timestamp': '2024-05-30T22:15:00.000',
#   'trip_end_timestamp': '2024-05-30T22:45:00.000',
#   'trip_seconds': '2236',
#   'trip_miles': '18.13',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '46',
#   'tips': '7.58',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '58.08',
#   'payment_type': 'Credit Card',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': '0fb0fab1dd16c6e2888dbc9df91c7ce1d2e00fd6',
#   'taxi_id': '5f88daef22c65f61d051338809a96d6bc7f471c4e2cd73a6a5cb0058dd3affb03f82eb2a344695f5cfb9da95399827a5fb8bcdcbdfedda9612bee3fd71b1537c',
#   'trip_start_timestamp': '2024-05-30T22:15:00.000',
#   'trip_end_timestamp': '2024-05-30T22:30:00.000',
#   'trip_seconds': '1140',
#   'trip_miles': '8.1',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '77',
#   'fare': '22',
#   'tips': '5.6',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '27.6',
#   'payment_type': 'Credit Card',
#   'company': 'U Taxicab',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.9867118',
#   'dropoff_centroid_longitude': '-87.663416405',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6634164054, 41.9867117999]}},
#  {'trip_id': '0fa58df429798ceb5c330a25a93e013089af0a6c',
#   'taxi_id': '697ada6eb0299a4956ac3305adc75c5b45342ae7c7cd7fb3b1da8509193a5557f4c95197847331cf9e13b68014933a5b93701b48d01af85c3f14bad553495da1',
#   'trip_start_timestamp': '2024-05-30T22:15:00.000',
#   'trip_end_timestamp': '2024-05-30T22:30:00.000',
#   'trip_seconds': '1200',
#   'trip_miles': '5.3',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '24',
#   'fare': '16.5',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '21.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '0dceb2ea56a75e3914aa2b5f1c49aff84f8f096a',
#   'taxi_id': '11a881b7291dab7fe4187136591e3c02f39adbf8d9d3f2ddefb20b564df268c96e2692fa310d85c661e0e4fe6fa223eff741e6c8708f865c3881dedb89dd80e7',
#   'trip_start_timestamp': '2024-05-30T22:15:00.000',
#   'trip_end_timestamp': '2024-05-30T22:30:00.000',
#   'trip_seconds': '1532',
#   'trip_miles': '13.76',
#   'pickup_census_tract': '17031980100',
#   'dropoff_census_tract': '17031080100',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '8',
#   'fare':
5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '33.5',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.953582125',
#   'pickup_centroid_longitude': '-87.72345239',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7234523905, 41.9535821253]},
#   'dropoff_centroid_latitude': '41.839086906',
#   'dropoff_centroid_longitude': '-87.714003807',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.714003807, 41.8390869059]}},
#  ...]

# %%
# 24042 rows

len(data)
# Out:
# 24042

# %%
taxi_trips = pd.DataFrame(data)

# %%
taxi_trips.head()
# Out:
#                                     trip_id  \
# 0  ef777f57091b1cd0f5c302d1f190d0d1014ca086
# 1  ee6084135f7b3f1a62f1cd2a1dab3b4e53668ba8
# 2  edc8f8072bba237799c6a534088b37899b7f698c
# 3  eb8ea7976d6c310aa74e298cdf05264fd0796d78
# 4  e9a2da3e7558c32786f3c6b1c0286f4b67d10b13
#
#                                              taxi_id     trip_start_timestamp  \
# 0  fd8880cb7750013a4527e205b41a2c68a1609aa33931c9...  2024-05-31T23:45:00.000
# 1  d1d88b89ceb6d753007b6e795e3c24f4bea905a51e9d47...  2024-05-31T23:45:00.000
# 2  e64eafef5ee4018e702bdcfdbd899fac9d49d630c5dbdc...  2024-05-31T23:45:00.000
# 3  c17582be31089967bcc79faa83fe8c0f7521a55e172fa8...  2024-05-31T23:45:00.000
# 4  8989b51001d4b9175be9aedeb003a6a611d1a312dfe6d3...  2024-05-31T23:45:00.000
#
#         trip_end_timestamp trip_seconds trip_miles pickup_census_tract  \
# 0  2024-06-01T00:15:00.000         1397      17.63         17031980000
# 1  2024-06-01T00:00:00.000          435       0.71         17031081600
# 2  2024-06-01T00:00:00.000          540        1.4                 NaN
# 3  2024-06-01T00:00:00.000          780       1.61         17031081700
# 4  2024-05-31T23:45:00.000          583       3.17                 NaN
#
#   dropoff_census_tract pickup_community_area dropoff_community_area   fare  \
# 0          17031081201                    76                      8   43.5
# 1          17031320100                     8                     32     10
# 2                  NaN                   NaN                    NaN   7.75
# 3          17031320600                     8                     32      9
# 4                  NaN                    24                      8  10.58
#
#   tips tolls extras trip_total payment_type           company  \
# 0  9.6     0      4       57.6  Credit Card      City Service
# 1  2.1     0      0       12.1       Mobile         Flash Cab
# 2    0     0      0       7.75         Cash         U Taxicab
# 3    0     0      0        9.5  Credit Card  Medallion Leasin
# 4    2     0      0      12.58       Mobile          Sun Taxi
#
#   pickup_centroid_latitude pickup_centroid_longitude  \
# 0              41.97907082             -87.903039661
# 1             41.892072635             -87.628874157
# 2                      NaN                       NaN
# 3             41.892042136              -87.63186395
# 4             41.901206994             -87.676355989
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.90303966...
# 1  {'type': 'Point', 'coordinates': [-87.62887415...
# 2                                                NaN
# 3  {'type': 'Point', 'coordinates': [-87.63186394...
# 4  {'type': 'Point', 'coordinates': [-87.67635598...
#
#   dropoff_centroid_latitude dropoff_centroid_longitude  \
# 0              41.899155613              -87.626210532
# 1              41.884987192              -87.620992913
# 2                       NaN                        NaN
# 3              41.870607372              -87.622172937
# 4              41.899602111              -87.633308037
#
#                            dropoff_centroid_location
# 0  {'type': 'Point', 'coordinates': [-87.62621053...
# 1  {'type': 'Point', 'coordinates': [-87.62099291...
# 2                                                NaN
# 3  {'type': 'Point', 'coordinates': [-87.62217293...
# 4  {'type': 'Point', 'coordinates': [-87.63330803...

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26751 entries, 0 to 26750
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     26751 non-null  object
#  1   taxi_id                     26751 non-null  object
#  2   trip_start_timestamp        26751 non-null  object
#  3   trip_end_timestamp          26751 non-null  object
#  4   trip_seconds                26742 non-null  object
#  5   trip_miles                  26751 non-null  object
#  6   pickup_census_tract         14975 non-null  object
#  7   dropoff_census_tract        14741 non-null  object
#  8   pickup_community_area       26131 non-null  object
#  9   dropoff_community_area      24851 non-null  object
#  10  fare                        26692 non-null  object
#  11  tips                        26692 non-null  object
#  12  tolls                       26692 non-null  object
#  13  extras                      26692 non-null  object
#  14  trip_total                  26692 non-null  object
#  15  payment_type                26751 non-null  object
#  16  company                     26751 non-null  object
#  17  pickup_centroid_latitude    26151 non-null  object
#  18  pickup_centroid_longitude   26151 non-null  object
#  19  pickup_centroid_location    26151 non-null  object
#  20  dropoff_centroid_latitude   24964 non-null  object
#  21  dropoff_centroid_longitude  24964 non-null  object
#  22  dropoff_centroid_location   24964 non-null  object
# dtypes: object(23)
# memory usage: 4.7+ MB

# %%
taxi_trips.describe()
# Out:
#                                          trip_id  \
# count                                      26751
# unique                                     26751
# top     6144ef68dab033f8a4741d2324763d0a4ee3d0a1
# freq                                           1
#
#                                                   taxi_id  \
# count                                               26751
# unique                                               2496
# top     dd38b7cebd5414ae2b17595c68048ff8745c5147487c6c...
# freq                                                   44
#
#            trip_start_timestamp       trip_end_timestamp trip_seconds  \
# count                     26751                    26751        26742
# unique                       96                      110         4626
# top     2024-05-31T18:15:00.000  2024-05-31T18:15:00.000            0
# freq                        491                      501          494
#
#        trip_miles pickup_census_tract dropoff_census_tract  \
# count       26751               14975                14741
# unique       2602                  89                  134
# top             0         17031980000          17031839100
# freq         3314                3542                 1641
#
#        pickup_community_area dropoff_community_area   fare   tips  tolls  \
# count                  26131                  24851  26692  26692  26692
# unique                    77                     77   1993   1215     33
# top                        8                      8      9      0      0
# freq                    6004                   6834   1067  11647  26515
#
#        extras trip_total payment_type    company pickup_centroid_latitude  \
# count   26692      26692        26751      26751                    26151
# unique    227       3288            7         35                      163
# top         0       3.25  Credit Card  Flash Cab              41.97907082
# freq    16910        475        12397       4895                     3542
#
#        pickup_centroid_longitude  \
# count                      26151
# unique                       163
# top                -87.903039661
# freq                        3542
#
#                                  pickup_centroid_location  \
# count                                               26151
# unique                                                163
# top     {'type': 'Point', 'coordinates': [-87.90303966...
# freq                                                 3542
#
#        dropoff_centroid_latitude dropoff_centroid_longitude  \
# count                      24964                      24964
# unique                       200                        200
# top                 41.880994471              -87.632746489
# freq                        1641                       1641
#
#                                 dropoff_centroid_location
# count                                               24964
# unique                                                200
# top     {'type': 'Point', 'coordinates': [-87.63274648...
# freq                                                 1641

# %%
taxi_trips[taxi_trips["fare"].isna()].sample(5)
# Out:
#                                         trip_id  \
# 11968  99ef35b82c2b46141e1f15d7c6df47b18605db8d
# 18775  b51088540e1d19c2cfc45928dfb6a66aea87fc51
# 21417  e121b183b152a9ea62c867edb949d89b2ee4fb96
# 15727  a81ea9dba3b8df929b52283f998754a1351cc4fa
# 25746  8806f770d797fdc6d37a56bd15b0ad7b00dc2bdc
#
#                                                  taxi_id  \
# 11968  4b034948aceedd53262ae713f864b0364953a1852b6b24...
# 18775  f4275d08eb48c554a46a407ad6cd014d5f1442eb1fb68d...
# 21417  cfbd7f55fa135ea0d514faa2bd53482c5e1397ced1ebcb...
# 15727  264b8aad6a6da00fe55c46c42a3d63fdafca5fa951fcbb...
# 25746  3fc884f85502edb774458a292f930240e1c67ca4acf02f...
#
#           trip_start_timestamp       trip_end_timestamp trip_seconds  \
# 11968  2024-05-31T15:30:00.000  2024-05-31T16:30:00.000         3588
# 18775  2024-05-31T11:30:00.000  2024-05-31T12:00:00.000         1710
# 21417  2024-05-31T09:45:00.000  2024-05-31T10:45:00.000         3849
# 15727  2024-05-31T13:15:00.000  2024-05-31T13:30:00.000          747
# 25746  2024-05-31T04:45:00.000  2024-05-31T05:00:00.000         1299
#
#       trip_miles pickup_census_tract dropoff_census_tract  \
# 11968      13.92                 NaN                  NaN
# 18775       4.13         17031081201          17031330100
# 21417      19.03                 NaN                  NaN
# 15727       2.46                 NaN                  NaN
# 25746      14.79                 NaN                  NaN
#
#       pickup_community_area dropoff_community_area fare tips tolls extras  \
# 11968                    76                     22  NaN  NaN   NaN    NaN
# 18775                     8                     33  NaN  NaN   NaN    NaN
# 21417                    76                      8  NaN  NaN   NaN    NaN
# 15727                     8                     28  NaN  NaN   NaN    NaN
# 25746                     6                     76  NaN  NaN   NaN    NaN
#
#       trip_total payment_type                       company  \
# 11968        NaN         Cash                      Sun Taxi
# 18775        NaN         Cash                     Flash Cab
# 21417        NaN         Cash                      Sun Taxi
# 15727        NaN       Mobile                      Sun Taxi
# 25746        NaN       Mobile  Blue Ribbon Taxi Association
#
#       pickup_centroid_latitude pickup_centroid_longitude  \
# 11968             41.980264315             -87.913624596
# 18775             41.899155613             -87.626210532
# 21417             41.980264315             -87.913624596
# 15727             41.899602111             -87.633308037
# 25746             41.944226601             -87.655998182
#
#                                 pickup_centroid_location  \
# 11968  {'type': 'Point', 'coordinates': [-87.91362459...
# 18775  {'type': 'Point', 'coordinates': [-87.62621053...
# 21417  {'type': 'Point', 'coordinates': [-87.91362459...
# 15727  {'type': 'Point', 'coordinates': [-87.63330803...
# 25746  {'type': 'Point', 'coordinates': [-87.65599818...
#
#       dropoff_centroid_latitude dropoff_centroid_longitude  \
# 11968               41.92276062              -87.699155343
# 18775              41.859349715              -87.617358006
# 21417              41.899602111              -87.633308037
# 15727              41.874005383               -87.66351755
# 25746              41.980264315              -87.913624596
#
#                                dropoff_centroid_location
# 11968  {'type': 'Point', 'coordinates': [-87.69915534...
# 18775  {'type': 'Point', 'coordinates': [-87.61735800...
# 21417  {'type': 'Point', 'coordinates': [-87.63330803...
# 15727  {'type': 'Point', 'coordinates': [-87.66351754...
# 25746  {'type': 'Point', 'coordinates': [-87.91362459...

# %% [markdown]
# ### Transformation: deal with NaN values

# %%
taxi_trips
# Out:
#                                         trip_id  \
# 0      ef777f57091b1cd0f5c302d1f190d0d1014ca086
# 1      ee6084135f7b3f1a62f1cd2a1dab3b4e53668ba8
# 2      edc8f8072bba237799c6a534088b37899b7f698c
# 3      eb8ea7976d6c310aa74e298cdf05264fd0796d78
# 4      e9a2da3e7558c32786f3c6b1c0286f4b67d10b13
# ...                                         ...
# 26746  4c9a3b8687541c2f2921e42ba1cc1b86653600d9
# 26747  4d513f944ad995c4afd1c0f6236016efe0d7c32c
# 26748  50d92390ea47845edd6347b8314fb300da271e1e
# 26749  588ef3db73035073e7a2b7331088c4e8e2cd73d8
# 26750  6144ef68dab033f8a4741d2324763d0a4ee3d0a1
#
#                                                  taxi_id  \
# 0      fd8880cb7750013a4527e205b41a2c68a1609aa33931c9...
# 1      d1d88b89ceb6d753007b6e795e3c24f4bea905a51e9d47
#       pickup_centroid_latitude pickup_centroid_longitude  \
# 0                  41.97907082             -87.903039661
# 1                 41.892072635             -87.628874157
# 2                          NaN                       NaN
# 3                 41.892042136              -87.63186395
# 4                 41.901206994             -87.676355989
# ...                        ...                       ...
# 26746              41.79259236             -87.769615453
# 26747             41.980264315             -87.913624596
# 26748             41.980264315             -87.913624596
# 26749             41.899602111             -87.633308037
# 26750             41.835117986             -87.618677767
#
#                                 pickup_centroid_location  \
# 0      {'type': 'Point', 'coordinates': [-87.90303966...
# 1      {'type': 'Point', 'coordinates': [-87.62887415...
# 2                                                    NaN
# 3      {'type': 'Point', 'coordinates': [-87.63186394...
# 4      {'type': 'Point', 'coordinates': [-87.67635598...
# ...                                                  ...
# 26746  {'type': 'Point', 'coordinates': [-87.76961545...
# 26747  {'type': 'Point', 'coordinates': [-87.91362459...
# 26748  {'type': 'Point', 'coordinates': [-87.91362459...
# 26749  {'type': 'Point', 'coordinates': [-87.63330803...
# 26750  {'type': 'Point', 'coordinates': [-87.61867776...
#
#       dropoff_centroid_latitude dropoff_centroid_longitude  \
# 0                  41.899155613              -87.626210532
# 1                  41.884987192              -87.620992913
# 2                           NaN                        NaN
# 3                  41.870607372              -87.622172937
# 4                  41.899602111              -87.633308037
# ...                         ...                        ...
# 26746              41.878865584              -87.625192142
# 26747              41.980264315              -87.913624596
# 26748              41.922686284              -87.649488729
# 26749              41.899602111              -87.633308037
# 26750              41.835117986              -87.618677767
#
#                                dropoff_centroid_location
# 0      {'type': 'Point', 'coordinates': [-87.62621053...
# 1      {'type': 'Point', 'coordinates': [-87.62099291...
# 2                                                    NaN
# 3      {'type': 'Point', 'coordinates': [-87.62217293...
# 4      {'type': 'Point', 'coordinates': [-87.63330803...
# ...                                                  ...
# 26746  {'type': 'Point', 'coordinates': [-87.62519214...
# 26747  {'type': 'Point', 'coordinates': [-87.91362459...
# 26748  {'type': 'Point', 'coordinates': [-87.64948872...
# 26749  {'type': 'Point', 'coordinates': [-87.63330803...
# 26750  {'type': 'Point', 'coordinates': [-87.61867776...
#
# [26751 rows x 23 columns]

# %%
taxi_trips.drop(["pickup_census_tract", "dropoff_census_tract"], axis=1, inplace=True)

# %%
taxi_trips.drop(["pickup_centroid_location", "dropoff_centroid_location"], axis=1, inplace=True)

# %%
taxi_trips.dropna(inplace=True)

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24570 entries, 0 to 26750
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     24570 non-null  object
#  1   taxi_id                     24570 non-null  object
#  2   trip_start_timestamp        24570 non-null  object
#  3   trip_end_timestamp          24570 non-null  object
#  4   trip_seconds                24570 non-null  object
#  5   trip_miles                  24570 non-null  object
#  6   pickup_community_area       24570 non-null  object
#  7   dropoff_community_area      24570 non-null  object
#  8   fare                        24570 non-null  object
#  9   tips                        24570 non-null  object
#  10  tolls                       24570 non-null  object
#  11  extras                      24570 non-null  object
#  12  trip_total                  24570 non-null  object
#  13  payment_type                24570 non-null  object
#  14  company                     24570 non-null  object
#  15  pickup_centroid_latitude    24570 non-null  object
#  16  pickup_centroid_longitude   24570 non-null  object
#  17  dropoff_centroid_latitude   24570 non-null  object
#  18  dropoff_centroid_longitude  24570 non-null  object
# dtypes: object(19)
# memory usage: 3.7+ MB

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24570 entries, 0 to 26750
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     24570 non-null  object
#  1   taxi_id                     24570 non-null  object
#  2   trip_start_timestamp        24570 non-null  object
#  3   trip_end_timestamp          24570 non-null  object
#  4   trip_seconds                24570 non-null  object
#  5   trip_miles                  24570 non-null  object
#  6   pickup_community_area       24570 non-null  object
#  7   dropoff_community_area      24570 non-null  object
#  8   fare                        24570 non-null  object
#  9   tips                        24570 non-null  object
#  10  tolls                       24570 non-null  object
#  11  extras                      24570 non-null  object
#  12  trip_total                  24570 non-null  object
#  13  payment_type                24570 non-null  object
#  14  company                     24570 non-null  object
#  15  pickup_centroid_latitude    24570 non-null  object
#  16  pickup_centroid_longitude   24570 non-null  object
#  17  dropoff_centroid_latitude   24570 non-null  object
#  18  dropoff_centroid_longitude  24570 non-null  object
# dtypes: object(19)
# memory usage: 3.7+ MB

# %% [markdown]
# # Transformation: renaming

# %%
taxi_trips.rename(columns={"pickup_community_area": "pickup_community_area_id", "dropoff_community_area": "dropoff_community_area_id"}, inplace=True)

# %%
taxi_trips.columns
# Out:
# Index(['trip_id', 'taxi_id', 'trip_start_timestamp', 'trip_end_timestamp',
#        'trip_seconds', 'trip_miles', 'pickup_community_area_id',
#        'dropoff_community_area_id', 'fare', 'tips', 'tolls', 'extras',
#        'trip_total', 'payment_type', 'company', 'pickup_centroid_latitude',
#        'pickup_centroid_longitude', 'dropoff_centroid_latitude',
#        'dropoff_centroid_longitude'],
#       dtype='object')

# %% [markdown]
# # Transformation: create helper column for weather

# %%
taxi_trips.head()
# Out:
#                                     trip_id  \
# 0  ef777f57091b1cd0f5c302d1f190d0d1014ca086
# 1  ee6084135f7b3f1a62f1cd2a1dab3b4e53668ba8
# 3  eb8ea7976d6c310aa74e298cdf05264fd0796d78
# 4  e9a2da3e7558c32786f3c6b1c0286f4b67d10b13
# 5  e881dc3db610f91ebc9efbc84c1da54e0adc0310
#
#                                              taxi_id     trip_start_timestamp  \
# 0  fd8880cb7750013a4527e205b41a2c68a1609aa33931c9...  2024-05-31T23:45:00.000
# 1  d1d88b89ceb6d753007b6e795e3c24f4bea905a51e9d47...  2024-05-31T23:45:00.000
# 3  c17582be31089967bcc79faa83fe8c0f7521a55e172fa8...  2024-05-31T23:45:00.000
# 4  8989b51001d4b9175be9aedeb003a6a611d1a312dfe6d3...  2024-05-31T23:45:00.000
# 5  c3c7eca7dbd2a69ff3195e717334343ed19de792129c84...  2024-05-31T23:45:00.000
#
#         trip_end_timestamp trip_seconds trip_miles pickup_community_area_id  \
# 0  2024-06-01T00:15:00.000         1397      17.63                       76
# 1  2024-06-01T00:00:00.000          435       0.71                        8
# 3  2024-06-01T00:00:00.000          780       1.61                        8
# 4  2024-05-31T23:45:00.000          583       3.17                       24
# 5  2024-05-31T23:45:00.000            9          0                       28
#
#   dropoff_community_area_id   fare tips tolls extras trip_total payment_type  \
# 0                         8   43.5  9.6     0      4       57.6  Credit Card
# 1                        32     10  2.1     0      0       12.1       Mobile
# 3                        32      9    0     0      0        9.5  Credit Card
# 4                         8  10.58    2     0      0      12.58       Mobile
# 5                        28   3.25    0     0      0       3.25         Cash
#
#             company pickup_centroid_latitude pickup_centroid_longitude  \
# 0      City Service              41.97907082             -87.903039661
# 1         Flash Cab             41.892072635             -87.628874157
# 3  Medallion Leasin             41.892042136              -87.63186395
# 4          Sun Taxi             41.901206994             -87.676355989
# 5        Globe Taxi             41.879255084             -87.642648998
#
#   dropoff_centroid_latitude dropoff_centroid_longitude
# 0              41.899155613              -87.626210532
# 1              41.884987192              -87.620992913
# 3              41.870607372              -87.622172937
# 4              41.899602111              -87.633308037
# 5              41.879255084              -87.642648998

# %%
taxi_trips["trip_start_timestamp"] = pd.to_datetime(taxi_trips["trip_start_timestamp"])
taxi_trips.dtypes
# Out:
# trip_id                               object
# taxi_id                               object
# trip_start_timestamp          datetime64[ns]
# trip_end_timestamp                    object
# trip_seconds                          object
# trip_miles                            object
# pickup_community_area_id              object
# dropoff_community_area_id             object
# fare                                  object
# tips                                  object
# tolls                                 object
# extras                                object
# trip_total                            object
# payment_type                          object
# company                               object
# pickup_centroid_latitude              object
# pickup_centroid_longitude             object
# dropoff_centroid_latitude             object
# dropoff_centroid_longitude            object
# dtype: object

# %%
taxi_trips["datetime_for_weather"] = taxi_trips["trip_start_timestamp"].dt.floor("H")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10300\89027745.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   taxi_trips["datetime_for_weather"] = taxi_trips["trip_start_timestamp"].dt.floor("H")

# %%
taxi_trips["datetime_for_weather"]
# Out:
# 0       2024-05-31 23:00:00
# 1       2024-05-31 23:00:00
# 3       2024-05-31 23:00:00
# 4       2024-05-31 23:00:00
# 5       2024-05-31 23:00:00
#                 ...
# 26746   2024-05-31 00:00:00
# 26747   2024-05-31 00:00:00
# 26748   2024-05-31 00:00:00
# 26749   2024-05-31 00:00:00
# 26750   2024-05-31 00:00:00
# Name: datetime_for_weather, Length: 24570, dtype: datetime64[ns]

# %% [markdown]
# ### Check joining the trips and weather data

# %%
# Get weather data and create a dataframe out of it

current_datetime = datetime.now() - relativedelta(months=2)

formatted_datetime = current_datetime.strftime("%Y-%m-%d")

url = "https://archive-api.open-meteo.com/v1/era5"

params = {
    "latitude": 41.85,
    "longitude": -87.65,
    "start_date": formatted_datetime,
    "end_date": formatted_datetime,
    "hourly": "temperature_2m,wind_speed_10m,rain,precipitation"
}

response = requests.get(url, params=params)

weather_data = response.json()

weather_data_filtered = {
    "datetime": weather_data["hourly"]["time"],
    "temperature": weather_data["hourly"]["temperature_2m"],
    "wind_speed": weather_data["hourly"]["wind_speed_10m"],
    "rain": weather_data["hourly"]["rain"],
    "precipitation": weather_data["hourly"]["precipitation"]
}

weather_df = pd.DataFrame(weather_data_filtered)

weather_df['datetime'] = pd.to_datetime(weather_df['datetime'])

weather_df.head()
# Out:
#              datetime  temperature  wind_speed  rain  precipitation
# 0 2024-05-31 00:00:00         14.5        11.0   0.0            0.0
# 1 2024-05-31 01:00:00         12.6        10.3   0.0            0.0
# 2 2024-05-31 02:00:00         11.5         7.9   0.0            0.0
# 3 2024-05-31 03:00:00         10.9         7.9   0.0            0.0
# 4 2024-05-31 04:00:00         10.8         7.3   0.0            0.0

# %%
taxi_trips_with_weather = taxi_trips.merge(weather_df, left_on = "datetime_for_weather", right_on = "datetime")

# %%
taxi_trips_with_weather.head()
# Out:
#                                     trip_id  \
# 0  ef777f57091b1cd0f5c302d1f190d0d1014ca086
# 1  ee6084135f7b3f1a62f1cd2a1dab3b4e53668ba8
# 2  eb8ea7976d6c310aa74e298cdf05264fd0796d78
# 3  e9a2da3e7558c32786f3c6b1c0286f4b67d10b13
# 4  e881dc3db610f91ebc9efbc84c1da54e0adc0310
#
#                                              taxi_id trip_start_timestamp  \
# 0  fd8880cb7750013a4527e205b41a2c68a1609aa33931c9...  2024-05-31 23:45:00
# 1  d1d88b89ceb6d753007b6e795e3c24f4bea905a51e9d47...  2024-05-31 23:45:00
# 2  c17582be31089967bcc79faa83fe8c0f7521a55e172fa8...  2024-05-31 23:45:00
# 3  8989b51001d4b9175be9aedeb003a6a611d1a312dfe6d3...  2024-05-31 23:45:00
# 4  c3c7eca7dbd2a69ff3195e717334343ed19de792129c84...  2024-05-31 23:45:00
#
#         trip_end_timestamp trip_seconds trip_miles pickup_community_area_id  \
# 0  2024-06-01T00:15:00.000         1397      17.63                       76
# 1  2024-06-01T00:00:00.000          435       0.71                        8
# 2  2024-06-01T00:00:00.000          780       1.61                        8
# 3  2024-05-31T23:45:00.000          583       3.17                       24
# 4  2024-05-31T23:45:00.000            9          0                       28
#
#   dropoff_community_area_id   fare tips tolls extras trip_total payment_type  \
# 0                         8   43.5  9.6     0      4       57.6  Credit Card
# 1                        32     10  2.1     0      0       12.1       Mobile
# 2                        32      9    0     0      0        9.5  Credit Card
# 3                         8  10.58    2     0      0      12.58       Mobile
# 4                        28   3.25    0     0      0       3.25         Cash
#
#             company pickup_centroid_latitude pickup_centroid_longitude  \
# 0      City Service              41.97907082             -87.903039661
# 1         Flash Cab             41.892072635             -87.628874157
# 2  Medallion Leasin             41.892042136              -87.63186395
# 3          Sun Taxi             41.901206994             -87.676355989
# 4        Globe Taxi             41.879255084             -87.642648998
#
#   dropoff_centroid_latitude dropoff_centroid_longitude datetime_for_weather  \
# 0              41.899155613              -87.626210532  2024-05-31 23:00:00
# 1              41.884987192              -87.620992913  2024-05-31 23:00:00
# 2              41.870607372              -87.622172937  2024-05-31 23:00:00
# 3              41.899602111              -87.633308037  2024-05-31 23:00:00
# 4              41.879255084              -87.642648998  2024-05-31 23:00:00
#
#              datetime  temperature  wind_speed  rain  precipitation
# 0 2024-05-31 23:00:00         21.9        15.5   0.0            0.0
# 1 2024-05-31 23:00:00         21.9        15.5   0.0            0.0
# 2 2024-05-31 23:00:00         21.9        15.5   0.0            0.0
# 3 2024-05-31 23:00:00         21.9        15.5   0.0            0.0
# 4 2024-05-31 23:00:00         21.9        15.5   0.0            0.0

# %% [markdown]
# ### Transformation: Datatype conversions

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24570 entries, 0 to 26750
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     24570 non-null  object
#  1   taxi_id                     24570 non-null  object
#  2   trip_start_timestamp        24570 non-null  datetime64[ns]
#  3   trip_end_timestamp          24570 non-null  object
#  4   trip_seconds                24570 non-null  object
#  5   trip_miles                  24570 non-null  object
#  6   pickup_community_area_id    24570 non-null  object
#  7   dropoff_community_area_id   24570 non-null  object
#  8   fare                        24570 non-null  object
#  9   tips                        24570 non-null  object
#  10  tolls                       24570 non-null  object
#  11  extras                      24570 non-null  object
#  12  trip_total                  24570 non-null  object
#  13  payment_type                24570 non-null  object
#  14  company                     24570 non-null  object
#  15  pickup_centroid_latitude    24570 non-null  object
#  16  pickup_centroid_longitude   24570 non-null  object
#  17  dropoff_centroid_latitude   24570 non-null  object
#  18  dropoff_centroid_longitude  24570 non-null  object
#  19  datetime_for_weather        24570 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(18)
# memory usage: 3.9+ MB

# %%
taxi_trips.head(5)
# Out:
#                                     trip_id  \
# 0  ef777f57091b1cd0f5c302d1f190d0d1014ca086
# 1  ee6084135f7b3f1a62f1cd2a1dab3b4e53668ba8
# 3  eb8ea7976d6c310aa74e298cdf05264fd0796d78
# 4  e9a2da3e7558c32786f3c6b1c0286f4b67d10b13
# 5  e881dc3db610f91ebc9efbc84c1da54e0adc0310
#
#                                              taxi_id trip_start_timestamp  \
# 0  fd8880cb7750013a4527e205b41a2c68a1609aa33931c9...  2024-05-31 23:45:00
# 1  d1d88b89ceb6d753007b6e795e3c24f4bea905a51e9d47...  2024-05-31 23:45:00
# 3  c17582be31089967bcc79faa83fe8c0f7521a55e172fa8...  2024-05-31 23:45:00
# 4  8989b51001d4b9175be9aedeb003a6a611d1a312dfe6d3...  2024-05-31 23:45:00
# 5  c3c7eca7dbd2a69ff3195e717334343ed19de792129c84...  2024-05-31 23:45:00
#
#         trip_end_timestamp trip_seconds trip_miles pickup_community_area_id  \
# 0  2024-06-01T00:15:00.000         1397      17.63                       76
# 1  2024-06-01T00:00:00.000          435       0.71                        8
# 3  2024-06-01T00:00:00.000          780       1.61                        8
# 4  2024-05-31T23:45:00.000          583       3.17                       24
# 5  2024-05-31T23:45:00.000            9          0                       28
#
#   dropoff_community_area_id   fare tips tolls extras trip_total payment_type  \
# 0                         8   43.5  9.6     0      4       57.6  Credit Card
# 1                        32     10  2.1     0      0       12.1       Mobile
# 3                        32      9    0     0      0        9.5  Credit Card
# 4                         8  10.58    2     0      0      12.58       Mobile
# 5                        28   3.25    0     0      0       3.25         Cash
#
#             company pickup_centroid_latitude pickup_centroid_longitude  \
# 0      City Service              41.97907082             -87.903039661
# 1         Flash Cab             41.892072635             -87.628874157
# 3  Medallion Leasin             41.892042136              -87.63186395
# 4          Sun Taxi             41.901206994             -87.676355989
# 5        Globe Taxi             41.879255084             -87.642648998
#
#   dropoff_centroid_latitude dropoff_centroid_longitude datetime_for_weather
# 0              41.899155613              -87.626210532  2024-05-31 23:00:00
# 1              41.884987192              -87.620992913  2024-05-31 23:00:00
# 3              41.870607372              -87.622172937  2024-05-31 23:00:00
# 4              41.899602111              -87.633308037  2024-05-31 23:00:00
# 5              41.879255084              -87.642648998  2024-05-31 23:00:00

# %%
# taxi_trips.describe()
data_types_dict = {
    "trip_end_timestamp": "datetime64[ns]",
    "trip_seconds": "int32",
    "trip_miles": "float",
    "pickup_community_area_id": "int8",
    "dropoff_community_area_id": "int8",
    "fare": "float",
    "tips": "float",
    "tolls": "float",
    "extras": "float",
    "trip_total": "float",
}
taxi_trips = taxi_trips.astype(data_types_dict)

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24570 entries, 0 to 26750
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     24570 non-null  object
#  1   taxi_id                     24570 non-null  object
#  2   trip_start_timestamp        24570 non-null  datetime64[ns]
#  3   trip_end_timestamp          24570 non-null  datetime64[ns]
#  4   trip_seconds                24570 non-null  int32
#  5   trip_miles                  24570 non-null  float64
#  6   pickup_community_area_id    24570 non-null  int8
#  7   dropoff_community_area_id   24570 non-null  int8
#  8   fare                        24570 non-null  float64
#  9   tips                        24570 non-null  float64
#  10  tolls                       24570 non-null  float64
#  11  extras                      24570 non-null  float64
#  12  trip_total                  24570 non-null  float64
#  13  payment_type                24570 non-null  object
#  14  company                     24570 non-null  object
#  15  pickup_centroid_latitude    24570 non-null  object
#  16  pickup_centroid_longitude   24570 non-null  object
#  17  dropoff_centroid_latitude   24570 non-null  object
#  18  dropoff_centroid_longitude  24570 non-null  object
#  19  datetime_for_weather        24570 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(6), int32(1), int8(2), object(8)
# memory usage: 3.5+ MB

# %%
taxi_trips.describe()
# Out:
#                 trip_start_timestamp             trip_end_timestamp  \
# count                          24570                          24570
# mean   2024-05-31 14:24:19.413919488  2024-05-31 14:48:38.021977856
# min              2024-05-31 00:00:00            2024-05-31 00:00:00
# 25%              2024-05-31 10:45:00            2024-05-31 11:15:00
# 50%              2024-05-31 14:45:00            2024-05-31 15:00:00
# 75%              2024-05-31 18:30:00            2024-05-31 18:45:00
# max              2024-05-31 23:45:00            2024-06-01 14:30:00
# std                              NaN                            NaN
#
#        trip_seconds    trip_miles  pickup_community_area_id  \
# count  24570.000000  24570.000000              24570.000000
# mean    1451.995075      5.991169                 33.526414
# min        0.000000      0.000000                  1.000000
# 25%      501.000000      0.970000                  8.000000
# 50%     1003.000000      2.750000                 32.000000
# 75%     1980.000000     10.540000                 46.000000
# max    63374.000000     57.690000                 77.000000
# std     1536.887964      6.845615                 24.981103
#
#        dropoff_community_area_id          fare          tips         tolls  \
# count               24570.000000  24570.000000  24570.000000  24570.000000
# mean                   24.960236     22.127126      3.217477      0.009399
# min                     1.000000      0.000000      0.000000      0.000000
# 25%                     8.000000      9.000000      0.000000      0.000000
# 50%                    28.000000     14.750000      2.000000      0.000000
# 75%                    32.000000     33.250000      4.500000      0.000000
# max                    77.000000   1300.000000    110.000000     29.000000
# std                    18.712583     22.466705      4.236144      0.269151
#
#              extras    trip_total           datetime_for_weather
# count  24570.000000  24570.000000                          24570
# mean       1.651182     27.227833  2024-05-31 14:01:52.967033088
# min        0.000000      0.000000            2024-05-31 00:00:00
# 25%        0.000000     11.000000            2024-05-31 10:00:00
# 50%        0.000000     17.775000            2024-05-31 14:00:00
# 75%        1.500000     40.000000            2024-05-31 18:00:00
# max     3155.550000   3175.550000            2024-05-31 23:00:00
# std       20.646504     32.814194                            NaN

# %% [markdown]
# ### Memory-usage

# %%
taxi_trips.memory_usage(deep=True).sum()
# Out:
# np.int64(17703775)

# %% [markdown]
# #### Sanitiy check

# %%
taxi_trips[taxi_trips["trip_end_timestamp"] == taxi_trips['trip_end_timestamp'].max()]
# Out:
#                                       trip_id  \
# 104  465965135af4ff465ddbee11d34faab08da9885c
#
#                                                taxi_id trip_start_timestamp  \
# 104  3732a30498120430b9e4f4221f528712e785455dd66df7...  2024-05-31 23:45:00
#
#      trip_end_timestamp  trip_seconds  trip_miles  pickup_community_area_id  \
# 104 2024-06-01 14:30:00         53247        4.44                         3
#
#      dropoff_community_area_id   fare  tips  tolls  extras  trip_total  \
# 104                          2  15.75   0.0    0.0     0.0       15.75
#
#     payment_type    company pickup_centroid_latitude  \
# 104         Cash  Flash Cab              41.96581197
#
#     pickup_centroid_longitude dropoff_centroid_latitude  \
# 104             -87.655878786              42.001571027
#
#     dropoff_centroid_longitude datetime_for_weather
# 104              -87.695012589  2024-05-31 23:00:00

# %%
taxi_trips[taxi_trips["trip_seconds"] == taxi_trips['trip_seconds'].max()]
# Out:
#                                         trip_id  \
# 13534  d72a437923ea2c90519d84f393bd3bfe0a85f91f
#
#                                                  taxi_id trip_start_timestamp  \
# 13534  5f4b687fcddac3ec50959a643b0068496ac8deb19f1599...  2024-05-31 14:30:00
#
#        trip_end_timestamp  trip_seconds  trip_miles  pickup_community_area_id  \
# 13534 2024-06-01 08:15:00         63374        0.03                         6
#
#        dropoff_community_area_id  fare  tips  tolls  extras  trip_total  \
# 13534                          6  8.75   0.0    0.0     0.0        8.75
#
#       payment_type    company pickup_centroid_latitude  \
# 13534         Cash  Flash Cab             41.944226601
#
#       pickup_centroid_longitude dropoff_centroid_latitude  \
# 13534             -87.655998182              41.944226601
#
#       dropoff_centroid_longitude datetime_for_weather
# 13534              -87.655998182  2024-05-31 14:00:00

# %%
taxi_trips[taxi_trips["fare"] == taxi_trips['fare'].max()]
# Out:
#                                         trip_id  \
# 19557  cd12637dd106361183b5e4cdf0365a7c2ecb3ca2
#
#                                                  taxi_id trip_start_timestamp  \
# 19557  d24d419085615e4f1184135c4e2fbce7458c52aab8378f...  2024-05-31 11:00:00
#
#        trip_end_timestamp  trip_seconds  trip_miles  pickup_community_area_id  \
# 19557 2024-05-31 11:00:00           235         0.0                        16
#
#        dropoff_community_area_id    fare  tips  tolls  extras  trip_total  \
# 19557                         16  1300.0   0.0    0.0     0.0      1300.0
#
#       payment_type                     company pickup_centroid_latitude  \
# 19557         Cash  Tac - Checker Cab Dispatch             41.953582125
#
#       pickup_centroid_longitude dropoff_centroid_latitude  \
# 19557              -87.72345239              41.953582125
#
#       dropoff_centroid_longitude datetime_for_weather
# 19557               -87.72345239  2024-05-31 11:00:00

# %%
taxi_trips.nlargest(10, "fare")
# Out:
#                                         trip_id  \
# 19557  cd12637dd106361183b5e4cdf0365a7c2ecb3ca2
# 12581  3796a536b5349057e6c1571f6d58d0c0efa1d5eb
# 16696  59716b12e42138b43748dbaa7770a07266ea9627
# 8367   dbb3f4f3b7dcc07c1042159be65cace5239079ad
# 13157  474f70636a1514b7940b0a7f40650f086ae89eb6
# 17378  cf613fb912e9867cd481c669bc1ce1d649f82993
# 18138  2ddf1ff18662c03f2604477c83dd43a9ae9034dd
# 18774  b5730cd5357382a1f4ea46889a6e297467976784
# 871    620dbec2cd7b54bb4d1f95ac177c2de657f8a04c
# 13180  5254d2619ab1f2e46aebc39401c8b33ff113c5cb
#
#                                                  taxi_id trip_start_timestamp  \
# 19557  d24d419085615e4f1184135c4e2fbce7458c52aab8378f...  2024-05-31 11:00:00
# 12581  bc8f828bfabea08242e8ba5d7283722378869f674da074...  2024-05-31 15:15:00
# 16696  f19b6b38529c21e161c145c467760a5897eb378f4a8d75...  2024-05-31 12:45:00
# 8367   6ef77e0e0e6d4b22a9c6f730b294a0b604c92cd43d557b...  2024-05-31 17:30:00
# 13157  4c4264f53bc23de0a1bc1150f1a490d89aaab4a8137304...  2024-05-31 14:45:00
# 17378  f19b6b38529c21e161c145c467760a5897eb378f4a8d75...  2024-05-31 12:15:00
# 18138  249d932165de24c10140f979fa81b350183cff7ac63099...  2024-05-31 12:00:00
# 18774  213cb87b9353531cbe1f6094a0456d586c651015cb15a5...  2024-05-31 11:30:00
# 871    ed17822a864c82f0ac8c3110918dacfa804f66b06d9668...  2024-05-31 22:45:00
# 13180  ed17822a864c82f0ac8c3110918dacfa804f66b06d9668...  2024-05-31 14:45:00
#
#        trip_end_timestamp  trip_seconds  trip_miles  pickup_community_area_id  \
#